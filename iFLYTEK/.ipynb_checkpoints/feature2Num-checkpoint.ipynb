# %%
import pandas as pd
import numpy as np

path = 'C:/Users/tangzz/Documents/Data/iFLYTEK/'
train = pd.read_csv(path+"train_feature.csv")
# test = pd.read_csv(path+"test_feature.csv")

# %%
import pickle
# 1
with open( path + 'dict/time_sort_dict.dat','rb') as f:
            time_sort_dict = pickle.load(f)
def time2Numbers(time):
    if time in time_sort_dict:
        time = time_sort_dict[time]
    else:
        time = 0
    return time
# 2
with open( path + 'dict/city_dict.dat','rb') as f:
            city_dict = pickle.load(f)
def city2Numbers(city):
    if city in city_dict:
        city = city_dict[city]
    else:
        city = 0
    return city
# 3
with open( path + 'dict/province_dict.dat','rb') as f:
        province_dict = pickle.load(f)
def province2Numbers(province):
    if province in province_dict:
        province = province_dict[province]
    else:
        province = 0
    return province
# 4
with open( path + 'dict/make_dict.dat','rb') as f:
    make_dict = pickle.load(f)
def make2Numbers(make):
    if make in make_dict:
        make = make_dict[make]
    else:
        make = 0
    return make
# 4
with open( path + 'dict/model_dict.dat','rb') as f:
    model_dict = pickle.load(f)
def model2Numbers(model):
    if model in model_dict:
        model = model_dict[model]
    else:
        model = 0
    return model
# 5
with open( path + 'dict/osv_os_name_dict.dat','rb') as f:
    osv_os_name_dict = pickle.load(f)
def osv_os_name2Numbers(osv_os_name):
    if osv_os_name in osv_os_name_dict:
        osv_os_name = osv_os_name_dict[osv_os_name]
    else:
        osv_os_name = 0
    return osv_os_name
# 6
def os_name2Numbers(os_name):
    if str(os_name) == 'ios':
        os_name = 1
    elif str(os_name)== 'android':
        os_name = 2
    else:
        os_name = 0
    return os_name
# 7
with open( path + 'dict/adid_dict.dat','rb') as f:
    adid_dict = pickle.load(f)
def adid2Numbers(adid):
    if adid in adid_dict:
        adid = adid_dict[adid]
    else:
        adid = 0
    return adid
# 8
with open( path + 'dict/advert_id_dict.dat','rb') as f:
    advert_id_dict = pickle.load(f)
def advert_id2Numbers(advert_id):
    if advert_id in advert_id_dict:
        advert_id = advert_id_dict[advert_id]
    else:
        advert_id = 0
    return advert_id
# 9
with open( path + 'dict/orderid_dict.dat','rb') as f:
    orderid_dict = pickle.load(f)
def orderid2Numbers(orderid):
    if orderid in orderid_dict:
        orderid = orderid_dict[orderid]
    else:
        orderid = 0
    return orderid
# 10
with open( path + 'dict/advert_industry_inner_dict.dat','rb') as f:
    advert_industry_inner_dict = pickle.load(f)
def advert_industry_inner2Numbers(advert_industry_inner):
    if advert_industry_inner in advert_industry_inner_dict:
        advert_industry_inner = advert_industry_inner_dict[advert_industry_inner]
    else:
        advert_industry_inner = 0
    return advert_industry_inner
# 11
with open( path + 'dict/app_cate_id_dict.dat','rb') as f:
    app_cate_id_dict = pickle.load(f)
def app_cate_id2Numbers(app_cate_id):
    if app_cate_id in app_cate_id_dict:
        app_cate_id = app_cate_id_dict[app_cate_id]
    else:
        app_cate_id = 0
    return app_cate_id

with open( path + 'dict/campaign_id_dict.dat','rb') as f:
    campaign_id_dict = pickle.load(f)
def campaign_id2Numbers(campaign_id):
    if campaign_id in campaign_id_dict:
        campaign_id = campaign_id_dict[campaign_id]
    else:
        campaign_id = 0
    return campaign_id
# 12
with open( path + 'dict/creative_id_dict.dat','rb') as f:
    creative_id_dict = pickle.load(f)
def creative_id2Numbers(creative_id):
    if creative_id in creative_id_dict:
        creative_id = creative_id_dict[creative_id]
    else:
        creative_id = 0
    return creative_id
# 13
with open( path + 'dict/creative_tp_dnf_dict.dat','rb') as f:
        creative_tp_dnf_dict = pickle.load(f)
def creative_tp_dnf2Numbers(creative_tp_dnf):
    if creative_tp_dnf in creative_tp_dnf_dict:
        creative_tp_dnf = creative_tp_dnf_dict[creative_tp_dnf]
    else:
        creative_tp_dnf = 0 
    return creative_tp_dnf
# 14
with open( path + 'dict/f_channel_dict.dat','rb') as f:
        f_channel_dict = pickle.load(f)
def f_channel2Numbers(f_channel):
    if f_channel in f_channel_dict:
        f_channel = f_channel_dict[f_channel]
    else:
        f_channel = 0
    return f_channel
# 15
with open( path + 'dict/app_id_dict.dat','rb') as f:
    app_id_dict = pickle.load(f)
def app_id2Numbers(app_id):
    if app_id in app_id_dict:
        app_id = app_id_dict[app_id]
    else:
        app_id = 0
    return app_id
# 16
with open( path + 'dict/inner_slot_id_dict.dat','rb') as f:
    inner_slot_id_dict = pickle.load(f)
def inner_slot_id2Numbers(inner_slot_id):
    if inner_slot_id in inner_slot_id_dict:
        inner_slot_id = inner_slot_id_dict[inner_slot_id]
    else:
        inner_slot_id = 0
    return inner_slot_id
# 17
def creative_is_jump2Numbers(creative_is_jump):
    jump = str(creative_is_jump)
    if jump[0] == 'T':
        creative_is_jump=1
    else:
        creative_is_jump=0
    return creative_is_jump
# 18
def creative_is_download2Numbers(creative_is_download):
    download = str(creative_is_download)
    if download[0] == 'T':
        creative_is_download=1
    else:
        creative_is_download=0
    return creative_is_download
# 19
with open( path + 'dict/advert_name_dict.dat','rb') as f:
        advert_namead_dict = pickle.load(f)
def advert_name2Numbers(advert_namead):
    tmp = str(advert_namead).replace('\n','')
    if tmp in advert_namead_dict:
        advert_namead = advert_namead_dict[tmp]
    else:
        advert_namead = 0
    return advert_namead
# 20--0
with open( path + 'dict/user_tags_class_dict.dat','rb') as f:
    user_tag_class_dict = pickle.load(f)
def user_tag_class2Numbers_0(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 0:
                classNum += 1
    return classNum
# 20--1
def user_tag_class2Numbers_1(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 1:
                classNum += 1
    return classNum
# 20--2
def user_tag_class2Numbers_2(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 2:
                classNum += 1
    return classNum
# 20--3
def user_tag_class2Numbers_3(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 3:
                classNum += 1
    return classNum
# 20--4
def user_tag_class2Numbers_4(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 4:
                classNum += 1
    return classNum
# 20--5
def user_tag_class2Numbers_5(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 5:
                classNum += 1
    return classNum
# 20--6
def user_tag_class2Numbers_6(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 6:
                classNum += 1
    return classNum
# 20--7
def user_tag_class2Numbers_7(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 7:
                classNum += 1
    return classNum
# 20--8
def user_tag_class2Numbers_8(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 8:
                classNum += 1
    return classNum
# 20--9
def user_tag_class2Numbers_9(user_tag_class):
    classNum = 0
    user_tag_class = str(user_tag_class).split(',')
    for line in user_tag_class:
        if line in user_tag_class_dict:
            if user_tag_class_dict[line]== 9:
                classNum += 1
    return classNum

def getsplit_osv(row):
    tmp = str(row)+'cc'
    if tmp[0].isdigit():
        return int(tmp[0])
    return 0

def getsplit_advert_industry_inner_1(advert_industry_inner_1):
    tmp = advert_industry_inner_1
    if '_' in tmp:
        tmp = tmp.split('_')
        return tmp[0]
    else:
        return 0
    
def getsplit_advert_industry_inner_2(advert_industry_inner_2):
    tmp = advert_industry_inner_2
    if '_' in tmp:
        tmp = tmp.split('_')
        return tmp[1]
    else:
        return 1
#
with open( path + 'dict/adid_campaign_id_dict.dat','rb') as f:
        adid_campaign_id_dict = pickle.load(f)
def adid_campaign_id2Numbers(adid_campaign_id):
    if adid_campaign_id in adid_campaign_id_dict:
        adid_campaign_id = adid_campaign_id_dict[adid_campaign_id]
    else:
        adid_campaign_id = 0
    return adid_campaign_id
#
with open( path + 'dict/adid_creative_id_dict.dat','rb') as f:
        adid_creative_id_dict = pickle.load(f)
def adid_creative_id2Numbers(adid_creative_id):
    if adid_creative_id in adid_creative_id_dict:
        adid_creative_id = adid_creative_id_dict[adid_creative_id]
    else:
        adid_creative_id = 0
    return adid_creative_id
#
with open( path + 'dict/adid_creative_type_dict.dat','rb') as f:
        adid_creative_type_dict = pickle.load(f)
def adid_creative_type2Numbers(adid_creative_type):
    if adid_creative_type in adid_creative_type_dict:
        adid_creative_type = adid_creative_type_dict[adid_creative_type]
    else:
        adid_creative_type = 0
    return adid_creative_type
#
with open( path + 'dict/campaign_id_creative_id_dict.dat','rb') as f:
        campaign_id_creative_id_dict = pickle.load(f)
def campaign_id_creative_id2Numbers(campaign_id_creative_id):
    if campaign_id_creative_id in campaign_id_creative_id_dict:
        campaign_id_creative_id = campaign_id_creative_id_dict[campaign_id_creative_id]
    else:
        campaign_id_creative_id = 0
    return campaign_id_creative_id
#
with open( path + 'dict/campaign_id_creative_type_dict.dat','rb') as f:
        campaign_id_creative_type_dict = pickle.load(f)
def campaign_id_creative_type2Numbers(campaign_id_creative_type):
    if campaign_id_creative_type in campaign_id_creative_type_dict:
        campaign_id_creative_type = campaign_id_creative_type_dict[campaign_id_creative_type]
    else:
        campaign_id_creative_type = 0
    return campaign_id_creative_type
#
with open( path + 'dict/creative_id_creative_type_dict.dat','rb') as f:
        creative_id_creative_type_dict = pickle.load(f)
def creative_id_creative_type2Numbers(creative_id_creative_type):
    if creative_id_creative_type in creative_id_creative_type_dict:
        creative_id_creative_type = creative_id_creative_type_dict[creative_id_creative_type]
    else:
        creative_id_creative_type = 0
    return creative_id_creative_type

# %%
# 1
with open( path + 'dict/user_tags_creative_type_label_dict.dat','rb') as f:
        user_tags_creative_type_label_dict = pickle.load(f)      
def user_tags_creative_type_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['creative_type'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_creative_type_label_dict:
                tmpNum = user_tags_creative_type_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum

# 2
with open( path + 'dict/user_tags_adid_label_dict.dat','rb') as f:
        user_tags_adid_label_dict = pickle.load(f)  
def user_tags_adid_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['adid'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_adid_label_dict:
                tmpNum = user_tags_adid_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum
# 3
with open( path + 'dict/user_tags_advert_id_label_dict.dat','rb') as f:
        user_tags_advert_id_label_dict = pickle.load(f) 
def user_tags_advert_id_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['advert_id'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_advert_id_label_dict:
                tmpNum = user_tags_advert_id_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum
# 4
with open( path + 'dict/user_tags_orderid_label_dict.dat','rb') as f:
        user_tags_orderid_label_dict = pickle.load(f)      
def user_tags_orderid_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['orderid'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_orderid_label_dict:
                tmpNum = user_tags_orderid_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum

# 5
with open( path + 'dict/user_tags_advert_industry_inner_label_dict.dat','rb') as f:
        user_tags_advert_industry_inner_label_dict = pickle.load(f)      
def user_tags_advert_industry_inner_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['advert_industry_inner'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_advert_industry_inner_label_dict:
                tmpNum = user_tags_advert_industry_inner_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum
# 6
with open( path + 'dict/user_tags_advert_name_label_dict.dat','rb') as f:
        user_tags_advert_name_label_dict = pickle.load(f)      
def user_tags_advert_name_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['advert_name'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_advert_name_label_dict:
                tmpNum = user_tags_advert_name_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum
# 7
with open( path + 'dict/user_tags_campaign_id_label_dict.dat','rb') as f:
        user_tags_campaign_id_label_dict = pickle.load(f)      
def user_tags_campaign_id_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['campaign_id'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_campaign_id_label_dict:
                tmpNum = user_tags_campaign_id_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum
# 8
with open( path + 'dict/user_tags_creative_id_label_dict.dat','rb') as f:
        user_tags_creative_id_label_dict = pickle.load(f)  
def user_tags_creative_id_label2Numbers(data_csv):
    retNum = []
    for i in range(len(data_csv)):
        user_tags = data_csv['user_tags'][i]
        creative_type = data_csv['creative_id'][i]
        lines_tags = str(user_tags).split(',')
        if lines_tags[0] == 'nan':
            lines_tags = '0'
        maxNum = 0
        for tags in lines_tags:
            tmp = str(creative_type)+':'+str(tags)
            if tmp in user_tags_campaign_id_label_dict:
                tmpNum = user_tags_campaign_id_label_dict[tmp]
            else:
                tmpNum = 0
            if tmpNum > maxNum:
                maxNum = tmpNum
        retNum.append(maxNum)
    return retNum
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
train['osv_os_name'] = train['osv'].map(str)+":"+train['os_name'].map(str)
train['adid_campaign_id']=train['adid'].map(str)+":"+train['campaign_id'].map(str)
train['adid_creative_id']=train['adid'].map(str)+":"+train['creative_id'].map(str)
train['adid_creative_type']=train['adid'].map(str)+":"+train['creative_type'].map(str)

train['campaign_id_creative_id']=train['campaign_id'].map(str)+":"+train['creative_id'].map(str)
train['campaign_id_creative_type']=train['campaign_id'].map(str)+":"+train['creative_type'].map(str)
train['creative_id_creative_type']=train['creative_id'].map(str)+":"+train['creative_type'].map(str)

train['user_tags_adid_label'] = user_tags_adid_label2Numbers(train)
train['user_tags_advert_id_label'] = user_tags_advert_id_label2Numbers(train)
train['user_tags_orderid_label'] = user_tags_orderid_label2Numbers(train)
train['user_tags_advert_industry_inner_label'] = user_tags_advert_industry_inner_label2Numbers(train)
train['user_tags_advert_name_label'] = user_tags_advert_name_label2Numbers(train)
train['user_tags_campaign_id_label'] = user_tags_campaign_id_label2Numbers(train)
train['user_tags_creative_id_label'] = user_tags_creative_id_label2Numbers(train)
train['user_tags_creative_type_label'] = user_tags_creative_type_label2Numbers(train)

train['time'] = train['time'].apply(time2Numbers)
train['city'] = train['city'].apply(city2Numbers)
train['province'] = train['province'].apply(province2Numbers)
train['make'] = train['make'].apply(make2Numbers)
train['model'] = train['model'].apply(model2Numbers)
train['os_name'] = train['os_name'].apply(os_name2Numbers)
train['osv_os_name'] = train['osv_os_name'].apply(osv_os_name2Numbers)
train['osv_First'] = train['osv'].apply(getsplit_osv)
train['app_cate_id'] = train['app_cate_id'].apply(app_cate_id2Numbers)
train['adid'] = train['adid'].apply(adid2Numbers)
train['advert_id'] = train['advert_id'].apply(advert_id2Numbers)
train['orderid'] = train['orderid'].apply(orderid2Numbers)

train['advert_industry_inner_1'] = train['advert_industry_inner'].apply(getsplit_advert_industry_inner_1)
train['advert_industry_inner_2'] = train['advert_industry_inner'].apply(getsplit_advert_industry_inner_2)
train['advert_industry_inner'] = train['advert_industry_inner'].apply(advert_industry_inner2Numbers)
train['creative_area'] = train['creative_width']*train['creative_height']

train['campaign_id'] = train['campaign_id'].apply(campaign_id2Numbers)
train['creative_id'] = train['creative_id'].apply(creative_id2Numbers)
train['creative_tp_dnf'] = train['creative_tp_dnf'].apply(creative_tp_dnf2Numbers)
train['f_channel'] = train['f_channel'].apply(f_channel2Numbers)
train['app_id'] = train['app_id'].apply(app_id2Numbers)
train['inner_slot_id'] = train['inner_slot_id'].apply(inner_slot_id2Numbers)
train['creative_is_jump'] = train['creative_is_jump'].apply(creative_is_jump2Numbers)
train['creative_is_download'] = train['creative_is_download'].apply(creative_is_download2Numbers)
train['advert_name'] = train['advert_name'].apply(advert_name2Numbers)
train['user_tags_0'] = train['user_tags'].apply(user_tag_class2Numbers_0)
train['user_tags_1'] = train['user_tags'].apply(user_tag_class2Numbers_1)
train['user_tags_2'] = train['user_tags'].apply(user_tag_class2Numbers_2)
train['user_tags_3'] = train['user_tags'].apply(user_tag_class2Numbers_3)
train['user_tags_4'] = train['user_tags'].apply(user_tag_class2Numbers_4)
train['user_tags_5'] = train['user_tags'].apply(user_tag_class2Numbers_5)
train['user_tags_6'] = train['user_tags'].apply(user_tag_class2Numbers_6)
train['user_tags_7'] = train['user_tags'].apply(user_tag_class2Numbers_7)
train['user_tags_8'] = train['user_tags'].apply(user_tag_class2Numbers_8)
train['user_tags_9'] = train['user_tags'].apply(user_tag_class2Numbers_9)

train['creative_type_user_tag_0'] = train['creative_type']*train['user_tags_0']
train['creative_type_user_tag_1'] = train['creative_type']*train['user_tags_1']
train['creative_type_user_tag_2'] = train['creative_type']*train['user_tags_2']
train['creative_type_user_tag_3'] = train['creative_type']*train['user_tags_3']
train['creative_type_user_tag_4'] = train['creative_type']*train['user_tags_4']
train['creative_type_user_tag_5'] = train['creative_type']*train['user_tags_5']
train['creative_type_user_tag_6'] = train['creative_type']*train['user_tags_6']
train['creative_type_user_tag_7'] = train['creative_type']*train['user_tags_7']
train['creative_type_user_tag_8'] = train['creative_type']*train['user_tags_8']
train['creative_type_user_tag_9'] = train['creative_type']*train['user_tags_9']

train['adid_user_tag_0'] = train['adid']*train['user_tags_0']
train['adid_user_tag_1'] = train['adid']*train['user_tags_1']
train['adid_user_tag_2'] = train['adid']*train['user_tags_2']
train['adid_user_tag_3'] = train['adid']*train['user_tags_3']
train['adid_user_tag_4'] = train['adid']*train['user_tags_4']
train['adid_user_tag_5'] = train['adid']*train['user_tags_5']
train['adid_user_tag_6'] = train['adid']*train['user_tags_6']
train['adid_user_tag_7'] = train['adid']*train['user_tags_7']
train['adid_user_tag_8'] = train['adid']*train['user_tags_8']
train['adid_user_tag_9'] = train['adid']*train['user_tags_9']

train['advert_id_user_tag_0'] = train['advert_id']*train['user_tags_0']
train['advert_id_user_tag_1'] = train['advert_id']*train['user_tags_1']
train['advert_id_user_tag_2'] = train['advert_id']*train['user_tags_2']
train['advert_id_user_tag_3'] = train['advert_id']*train['user_tags_3']
train['advert_id_user_tag_4'] = train['advert_id']*train['user_tags_4']
train['advert_id_user_tag_5'] = train['advert_id']*train['user_tags_5']
train['advert_id_user_tag_6'] = train['advert_id']*train['user_tags_6']
train['advert_id_user_tag_7'] = train['advert_id']*train['user_tags_7']
train['advert_id_user_tag_8'] = train['advert_id']*train['user_tags_8']
train['advert_id_user_tag_9'] = train['advert_id']*train['user_tags_9']

train['orderid_user_tag_0'] = train['orderid']*train['user_tags_0']
train['orderid_user_tag_1'] = train['orderid']*train['user_tags_1']
train['orderid_user_tag_2'] = train['orderid']*train['user_tags_2']
train['orderid_user_tag_3'] = train['orderid']*train['user_tags_3']
train['orderid_user_tag_4'] = train['orderid']*train['user_tags_4']
train['orderid_user_tag_5'] = train['orderid']*train['user_tags_5']
train['orderid_user_tag_6'] = train['orderid']*train['user_tags_6']
train['orderid_user_tag_7'] = train['orderid']*train['user_tags_7']
train['orderid_user_tag_8'] = train['orderid']*train['user_tags_8']
train['orderid_user_tag_9'] = train['orderid']*train['user_tags_9']

train['campaign_id_user_tag_0'] = train['campaign_id']*train['user_tags_0']
train['campaign_id_user_tag_1'] = train['campaign_id']*train['user_tags_1']
train['campaign_id_user_tag_2'] = train['campaign_id']*train['user_tags_2']
train['campaign_id_user_tag_3'] = train['campaign_id']*train['user_tags_3']
train['campaign_id_user_tag_4'] = train['campaign_id']*train['user_tags_4']
train['campaign_id_user_tag_5'] = train['campaign_id']*train['user_tags_5']
train['campaign_id_user_tag_6'] = train['campaign_id']*train['user_tags_6']
train['campaign_id_user_tag_7'] = train['campaign_id']*train['user_tags_7']
train['campaign_id_user_tag_8'] = train['campaign_id']*train['user_tags_8']
train['campaign_id_user_tag_9'] = train['campaign_id']*train['user_tags_9']

train['creative_id_user_tag_0'] = train['creative_id']*train['user_tags_0']
train['creative_id_user_tag_1'] = train['creative_id']*train['user_tags_1']
train['creative_id_user_tag_2'] = train['creative_id']*train['user_tags_2']
train['creative_id_user_tag_3'] = train['creative_id']*train['user_tags_3']
train['creative_id_user_tag_4'] = train['creative_id']*train['user_tags_4']
train['creative_id_user_tag_5'] = train['creative_id']*train['user_tags_5']
train['creative_id_user_tag_6'] = train['creative_id']*train['user_tags_6']
train['creative_id_user_tag_7'] = train['creative_id']*train['user_tags_7']
train['creative_id_user_tag_8'] = train['creative_id']*train['user_tags_8']
train['creative_id_user_tag_9'] = train['creative_id']*train['user_tags_9']

train['creative_area_user_tag_0'] = train['creative_area']*train['user_tags_0']
train['creative_area_user_tag_1'] = train['creative_area']*train['user_tags_1']
train['creative_area_user_tag_2'] = train['creative_area']*train['user_tags_2']
train['creative_area_user_tag_3'] = train['creative_area']*train['user_tags_3']
train['creative_area_user_tag_4'] = train['creative_area']*train['user_tags_4']
train['creative_area_user_tag_5'] = train['creative_area']*train['user_tags_5']
train['creative_area_user_tag_6'] = train['creative_area']*train['user_tags_6']
train['creative_area_user_tag_7'] = train['creative_area']*train['user_tags_7']
train['creative_area_user_tag_8'] = train['creative_area']*train['user_tags_8']
train['creative_area_user_tag_9'] = train['creative_area']*train['user_tags_9']

train['adid_campaign_id']=train['adid_campaign_id'].apply(adid_campaign_id2Numbers)
train['adid_creative_id']=train['adid_creative_id'].apply(adid_creative_id2Numbers)
train['adid_creative_type']=train['adid_creative_type'].apply(adid_creative_type2Numbers)
train['campaign_id_creative_id']=train['campaign_id_creative_id'].apply(campaign_id_creative_id2Numbers)
train['campaign_id_creative_type']=train['campaign_id_creative_type'].apply(campaign_id_creative_type2Numbers)
train['creative_id_creative_type']=train['creative_id_creative_type'].apply(creative_id_creative_type2Numbers)

new_train = train.drop(['instance_id','user_tags','osv','app_paid','creative_has_deeplink','creative_is_voicead','creative_is_js','click\n'],axis=1)
new_train.to_csv(path + 'train_new_number_feature.csv')

# %%
# test['osv_os_name'] = test['osv'].map(str)+":"+test['os_name'].map(str)
# test['adid_campaign_id']=test['adid'].map(str)+":"+test['campaign_id'].map(str)
# test['adid_creative_id']=test['adid'].map(str)+":"+test['creative_id'].map(str)
# test['adid_creative_type']=test['adid'].map(str)+":"+test['creative_type'].map(str)

# test['campaign_id_creative_id']=test['campaign_id'].map(str)+":"+test['creative_id'].map(str)
# test['campaign_id_creative_type']=test['campaign_id'].map(str)+":"+test['creative_type'].map(str)
# test['creative_id_creative_type']=test['creative_id'].map(str)+":"+test['creative_type'].map(str)

# test['user_tags_adid_label'] = user_tags_adid_label2Numbers(test)
# test['user_tags_advert_id_label'] = user_tags_advert_id_label2Numbers(test)
# test['user_tags_orderid_label'] = user_tags_orderid_label2Numbers(test)
# test['user_tags_advert_industry_inner_label'] = user_tags_advert_industry_inner_label2Numbers(test)
# test['user_tags_advert_name_label'] = user_tags_advert_name_label2Numbers(test)
# test['user_tags_campaign_id_label'] = user_tags_campaign_id_label2Numbers(test)
# test['user_tags_creative_id_label'] = user_tags_creative_id_label2Numbers(test)
# test['user_tags_creative_type_label'] = user_tags_creative_type_label2Numbers(test)

# test['time'] = test['time'].apply(time2Numbers)
# test['city'] = test['city'].apply(city2Numbers)
# test['province'] = test['province'].apply(province2Numbers)
# test['make'] = test['make'].apply(make2Numbers)
# test['model'] = test['model'].apply(model2Numbers)
# test['os_name'] = test['os_name'].apply(os_name2Numbers)
# test['osv_os_name'] = test['osv_os_name'].apply(osv_os_name2Numbers)
# test['osv_First'] = test['osv'].apply(getsplit_osv)
# test['app_cate_id'] = test['app_cate_id'].apply(app_cate_id2Numbers)
# test['adid'] = test['adid'].apply(adid2Numbers)
# test['advert_id'] = test['advert_id'].apply(advert_id2Numbers)
# test['orderid'] = test['orderid'].apply(orderid2Numbers)

# test['advert_industry_inner_1'] = test['advert_industry_inner'].apply(getsplit_advert_industry_inner_1)
# test['advert_industry_inner_2'] = test['advert_industry_inner'].apply(getsplit_advert_industry_inner_2)
# test['advert_industry_inner'] = test['advert_industry_inner'].apply(advert_industry_inner2Numbers)
# test['creative_area'] = test['creative_width']*test['creative_height']

# test['campaign_id'] = test['campaign_id'].apply(campaign_id2Numbers)
# test['creative_id'] = test['creative_id'].apply(creative_id2Numbers)
# test['creative_tp_dnf'] = test['creative_tp_dnf'].apply(creative_tp_dnf2Numbers)
# test['f_channel'] = test['f_channel'].apply(f_channel2Numbers)
# test['app_id'] = test['app_id'].apply(app_id2Numbers)
# test['inner_slot_id'] = test['inner_slot_id'].apply(inner_slot_id2Numbers)
# test['creative_is_jump'] = test['creative_is_jump'].apply(creative_is_jump2Numbers)
# test['creative_is_download'] = test['creative_is_download'].apply(creative_is_download2Numbers)
# test['advert_name'] = test['advert_name\n'].apply(advert_name2Numbers)
# test['user_tags_0'] = test['user_tags'].apply(user_tag_class2Numbers_0)
# test['user_tags_1'] = test['user_tags'].apply(user_tag_class2Numbers_1)
# test['user_tags_2'] = test['user_tags'].apply(user_tag_class2Numbers_2)
# test['user_tags_3'] = test['user_tags'].apply(user_tag_class2Numbers_3)
# test['user_tags_4'] = test['user_tags'].apply(user_tag_class2Numbers_4)
# test['user_tags_5'] = test['user_tags'].apply(user_tag_class2Numbers_5)
# test['user_tags_6'] = test['user_tags'].apply(user_tag_class2Numbers_6)
# test['user_tags_7'] = test['user_tags'].apply(user_tag_class2Numbers_7)
# test['user_tags_8'] = test['user_tags'].apply(user_tag_class2Numbers_8)
# test['user_tags_9'] = test['user_tags'].apply(user_tag_class2Numbers_9)

# test['creative_type_user_tag_0'] = test['creative_type']*test['user_tags_0']
# test['creative_type_user_tag_1'] = test['creative_type']*test['user_tags_1']
# test['creative_type_user_tag_2'] = test['creative_type']*test['user_tags_2']
# test['creative_type_user_tag_3'] = test['creative_type']*test['user_tags_3']
# test['creative_type_user_tag_4'] = test['creative_type']*test['user_tags_4']
# test['creative_type_user_tag_5'] = test['creative_type']*test['user_tags_5']
# test['creative_type_user_tag_6'] = test['creative_type']*test['user_tags_6']
# test['creative_type_user_tag_7'] = test['creative_type']*test['user_tags_7']
# test['creative_type_user_tag_8'] = test['creative_type']*test['user_tags_8']
# test['creative_type_user_tag_9'] = test['creative_type']*test['user_tags_9']

# test['adid_user_tag_0'] = test['adid']*test['user_tags_0']
# test['adid_user_tag_1'] = test['adid']*test['user_tags_1']
# test['adid_user_tag_2'] = test['adid']*test['user_tags_2']
# test['adid_user_tag_3'] = test['adid']*test['user_tags_3']
# test['adid_user_tag_4'] = test['adid']*test['user_tags_4']
# test['adid_user_tag_5'] = test['adid']*test['user_tags_5']
# test['adid_user_tag_6'] = test['adid']*test['user_tags_6']
# test['adid_user_tag_7'] = test['adid']*test['user_tags_7']
# test['adid_user_tag_8'] = test['adid']*test['user_tags_8']
# test['adid_user_tag_9'] = test['adid']*test['user_tags_9']

# test['advert_id_user_tag_0'] = test['advert_id']*test['user_tags_0']
# test['advert_id_user_tag_1'] = test['advert_id']*test['user_tags_1']
# test['advert_id_user_tag_2'] = test['advert_id']*test['user_tags_2']
# test['advert_id_user_tag_3'] = test['advert_id']*test['user_tags_3']
# test['advert_id_user_tag_4'] = test['advert_id']*test['user_tags_4']
# test['advert_id_user_tag_5'] = test['advert_id']*test['user_tags_5']
# test['advert_id_user_tag_6'] = test['advert_id']*test['user_tags_6']
# test['advert_id_user_tag_7'] = test['advert_id']*test['user_tags_7']
# test['advert_id_user_tag_8'] = test['advert_id']*test['user_tags_8']
# test['advert_id_user_tag_9'] = test['advert_id']*test['user_tags_9']

# test['orderid_user_tag_0'] = test['orderid']*test['user_tags_0']
# test['orderid_user_tag_1'] = test['orderid']*test['user_tags_1']
# test['orderid_user_tag_2'] = test['orderid']*test['user_tags_2']
# test['orderid_user_tag_3'] = test['orderid']*test['user_tags_3']
# test['orderid_user_tag_4'] = test['orderid']*test['user_tags_4']
# test['orderid_user_tag_5'] = test['orderid']*test['user_tags_5']
# test['orderid_user_tag_6'] = test['orderid']*test['user_tags_6']
# test['orderid_user_tag_7'] = test['orderid']*test['user_tags_7']
# test['orderid_user_tag_8'] = test['orderid']*test['user_tags_8']
# test['orderid_user_tag_9'] = test['orderid']*test['user_tags_9']

# test['campaign_id_user_tag_0'] = test['campaign_id']*test['user_tags_0']
# test['campaign_id_user_tag_1'] = test['campaign_id']*test['user_tags_1']
# test['campaign_id_user_tag_2'] = test['campaign_id']*test['user_tags_2']
# test['campaign_id_user_tag_3'] = test['campaign_id']*test['user_tags_3']
# test['campaign_id_user_tag_4'] = test['campaign_id']*test['user_tags_4']
# test['campaign_id_user_tag_5'] = test['campaign_id']*test['user_tags_5']
# test['campaign_id_user_tag_6'] = test['campaign_id']*test['user_tags_6']
# test['campaign_id_user_tag_7'] = test['campaign_id']*test['user_tags_7']
# test['campaign_id_user_tag_8'] = test['campaign_id']*test['user_tags_8']
# test['campaign_id_user_tag_9'] = test['campaign_id']*test['user_tags_9']

# test['creative_id_user_tag_0'] = test['creative_id']*test['user_tags_0']
# test['creative_id_user_tag_1'] = test['creative_id']*test['user_tags_1']
# test['creative_id_user_tag_2'] = test['creative_id']*test['user_tags_2']
# test['creative_id_user_tag_3'] = test['creative_id']*test['user_tags_3']
# test['creative_id_user_tag_4'] = test['creative_id']*test['user_tags_4']
# test['creative_id_user_tag_5'] = test['creative_id']*test['user_tags_5']
# test['creative_id_user_tag_6'] = test['creative_id']*test['user_tags_6']
# test['creative_id_user_tag_7'] = test['creative_id']*test['user_tags_7']
# test['creative_id_user_tag_8'] = test['creative_id']*test['user_tags_8']
# test['creative_id_user_tag_9'] = test['creative_id']*test['user_tags_9']

# test['creative_area_user_tag_0'] = test['creative_area']*test['user_tags_0']
# test['creative_area_user_tag_1'] = test['creative_area']*test['user_tags_1']
# test['creative_area_user_tag_2'] = test['creative_area']*test['user_tags_2']
# test['creative_area_user_tag_3'] = test['creative_area']*test['user_tags_3']
# test['creative_area_user_tag_4'] = test['creative_area']*test['user_tags_4']
# test['creative_area_user_tag_5'] = test['creative_area']*test['user_tags_5']
# test['creative_area_user_tag_6'] = test['creative_area']*test['user_tags_6']
# test['creative_area_user_tag_7'] = test['creative_area']*test['user_tags_7']
# test['creative_area_user_tag_8'] = test['creative_area']*test['user_tags_8']
# test['creative_area_user_tag_9'] = test['creative_area']*test['user_tags_9']

# test['adid_campaign_id']=test['adid_campaign_id'].apply(adid_campaign_id2Numbers)
# test['adid_creative_id']=test['adid_creative_id'].apply(adid_creative_id2Numbers)
# test['adid_creative_type']=test['adid_creative_type'].apply(adid_creative_type2Numbers)
# test['campaign_id_creative_id']=test['campaign_id_creative_id'].apply(campaign_id_creative_id2Numbers)
# test['campaign_id_creative_type']=test['campaign_id_creative_type'].apply(campaign_id_creative_type2Numbers)
# test['creative_id_creative_type']=test['creative_id_creative_type'].apply(creative_id_creative_type2Numbers)

# new_test = test.drop(['instance_id','user_tags','osv','app_paid','creative_has_deeplink','creative_is_voicead','creative_is_js','advert_name\n'],axis=1)
# new_test.to_csv(path + 'test_new_number_feature.csv')
